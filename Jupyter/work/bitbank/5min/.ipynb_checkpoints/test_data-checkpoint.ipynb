# %%
import pytest
import pickle
import datetime

# %%
type = '5min'
save_dir = './data/'
start = '20180601'
end = '20180920'
format = '%Y%m%d'
day = datetime.datetime.strptime(start, format)
end_day = datetime.datetime.strptime(end, format)
iteration = 0
list = []

# %%
while iteration < 1000:
    iteration += 1
    day_str = day.strftime(format)
    with open(save_dir+day_str+'_'+type+'.pkl', 'rb') as f:
        list.append(pickle.load(f))
    day += datetime.timedelta(days=1)
    if day >= end_day:
        break

# %%
def testData():
    # 全体の要素数
    assert list.len() == 112
    
    # 各要素のDataFrame数
    for i in range(list.len()):
        em = list[i]
        assert len(em) == 228
        assert len(em.columns) == 6

# %%
print(list[0])
# Out:
#        open    high     low     end turnover                time
# 0    816451  817650  816000  817650   2.8433 2018-06-01 00:00:00
# 1    817735  821300  817735  819254   7.2543 2018-06-01 00:05:00
# 2    819254  820170  818088  818321   9.6522 2018-06-01 00:10:00
# 3    818100  819232  817515  818509   4.6123 2018-06-01 00:15:00
# 4    818587  820015  818000  819231   4.9464 2018-06-01 00:20:00
# 5    819001  820199  818207  820192   3.2847 2018-06-01 00:25:00
# 6    820144  820154  818870  818870   1.9347 2018-06-01 00:30:00
# 7    819333  819662  818586  819436   1.1010 2018-06-01 00:35:00
# 8    819434  819894  819434  819873   4.4582 2018-06-01 00:40:00
# 9    819536  820048  819434  820048   3.7614 2018-06-01 00:45:00
# 10   820099  821222  817777  818518  11.2181 2018-06-01 00:50:00
# 11   818578  820655  817858  819918   6.3689 2018-06-01 00:55:00
# 12   819540  820000  817990  818500   4.8031 2018-06-01 01:00:00
# 13   818505  818505  817000  817503   5.0994 2018-06-01 01:05:00
# 14   817496  818358  816006  818005   5.8100 2018-06-01 01:10:00
# 15   818396  819200  817990  819200   4.3432 2018-06-01 01:15:00
# 16   819250  819750  819016  819750   1.0716 2018-06-01 01:20:00
# 17   819609  820230  819348  819531   3.1704 2018-06-01 01:25:00
# 18   819532  820250  818360  818360   3.4622 2018-06-01 01:30:00
# 19   819183  820324  819008  819956   1.8104 2018-06-01 01:35:00
# 20   819946  820279  819060  819828   1.9252 2018-06-01 01:40:00
# 21   820034  820034  819293  819293   1.8866 2018-06-01 01:45:00
# 22   819363  819535  818281  818658   2.7141 2018-06-01 01:50:00
# 23   819365  819534  818318  818466   2.1361 2018-06-01 01:55:00
# 24   818319  820319  817500  819971   9.0563 2018-06-01 02:00:00
